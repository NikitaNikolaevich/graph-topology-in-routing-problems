# %%
import sys
sys.path.append("E:/Roman/GitHub/graph-topology-in-routing-problems")

# %%
from ride.grapher import GraphProcessor, GraphRunner
from ride.utils import DataGetter
from ride.plotter import visualisation, box_visualisation

# %%
G = DataGetter.download_graph(id="R44915")

# %%
# Находим набор рабочих resolutions, ks, (v1, e1) для каждого графа
resolutions, ks, v1, e1 = GraphProcessor.search_resolutions(G, k_max=0.6)

# %%
output, all_errors = GraphRunner.test(G, resolutions, k=5, weight='dsfrthj')
# Out:
# Тестирование на начальном графе:
#
# Тестирование на центроидах:
#
# Тестирование на центроидах:
#
# Тестирование на центроидах:
#
# Тестирование на центроидах:
#
# Тестирование на центроидах:
#
# Тестирование на центроидах:
#
# Тестирование на центроидах:
#
# Тестирование на центроидах:
#
# Тестирование на центроидах:

# %%
# Визуализация времени работы по ks и формуле
visualisation(G, v1, e1, True, False)    
box_visualisation(G, output['time_preprocess_dijkstra_on_centroid_len'], output['time_dijkstra_base'].iloc[0].item(), all_errors, True, False)
# Out:
# E:\Roman/GitHub/graph-topology-in-routing-problems\ride\plotter.py:39: UserWarning: Legend does not support handles for Axes instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   ax1.legend(lines, [l.get_label() for l in lines])

# %%
output
# Out:
#       ks  errors_percent  time_preprocess_g_centroid_creation  \
# 0  0.013        9.489608                            10.229994
# 1  0.024       13.564771                             9.003031
# 2  0.044        9.223448                            10.395043
# 3  0.076        9.966028                            14.279955
# 4  0.129        5.466287                            20.637002
# 5  0.218        6.786256                            31.996041
# 6  0.357       10.423162                            47.231000
# 7  0.595        5.981851                            70.131004
# 8  0.908        0.202771                            91.602044
#
#    time_preprocess_dijkstra_on_centroid_len  time_dijkstra_base    speedup
# 0                                  0.024997            0.194982   7.800052
# 1                                  0.020002            0.194982   9.748042
# 2                                  0.016000            0.194982  12.186687
# 3                                  0.040998            0.194982   4.755827
# 4                                  0.020001            0.194982   9.748391
# 5                                  0.029002            0.194982   6.723106
# 6                                  0.047967            0.194982   4.064874
# 7                                  0.205957            0.194982   0.946708
# 8                                  0.116999            0.194982   1.666528
